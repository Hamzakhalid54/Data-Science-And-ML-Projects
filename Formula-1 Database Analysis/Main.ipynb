# %%
# Upload the CSV files
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5b00ba96-eeef-4546-8ccf-09d7d60951db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b00ba96-eeef-4546-8ccf-09d7d60951db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import io

# Extract the contents of the zip file
with zipfile.ZipFile(io.BytesIO(uploaded['f1db_csv.zip']), 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
from F1db import F1DB

# Create an instance of F1DB
f1_db = F1DB()

f1_db.import_csv("circuits.csv", "circuits")
f1_db.import_csv("constructor_results.csv", "constructor_results")
f1_db.import_csv("constructor_standings.csv", "constructor_standings")
f1_db.import_csv("constructors.csv", "constructors")
f1_db.import_csv("driver_standings.csv", "driver_standings")
f1_db.import_csv("drivers.csv", "drivers")
f1_db.import_csv("lap_times.csv", "lap_times")
f1_db.import_csv("pit_stops.csv", "pit_stops")
f1_db.import_csv("qualifying.csv", "qualifying")
f1_db.import_csv("races.csv", "races")
f1_db.import_csv("results.csv", "results")
f1_db.import_csv("seasons.csv", "seasons")
f1_db.import_csv("sprint_results.csv", "sprint_results")
f1_db.import_csv("status.csv", "status")

# %%
query_result = f1_db.conn.execute("SELECT * FROM circuits;").fetchall()
print(query_result)
# Out:
# [(1, 'albert_park', 'Albert Park Grand Prix Circuit', 'Melbourne', 'Australia', -37.8497, 144.968, 10, 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit'), (2, 'sepang', 'Sepang International Circuit', 'Kuala Lumpur', 'Malaysia', 2.76083, 101.738, 18, 'http://en.wikipedia.org/wiki/Sepang_International_Circuit'), (3, 'bahrain', 'Bahrain International Circuit', 'Sakhir', 'Bahrain', 26.0325, 50.5106, 7, 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit'), (4, 'catalunya', 'Circuit de Barcelona-Catalunya', 'Montmeló', 'Spain', 41.57, 2.26111, 109, 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya'), (5, 'istanbul', 'Istanbul Park', 'Istanbul', 'Turkey', 40.9517, 29.405, 130, 'http://en.wikipedia.org/wiki/Istanbul_Park'), (6, 'monaco', 'Circuit de Monaco', 'Monte-Carlo', 'Monaco', 43.7347, 7.42056, 7, 'http://en.wikipedia.org/wiki/Circuit_de_Monaco'), (7, 'villeneuve', 'Circuit Gilles Villeneuve', 'Montreal', 'Canada', 45.5, -73.5228, 13, 'http://en.wikipedia
# ...

# %%
from VisQueryF1DB import VisQueryF1DB
from QueryF1DB import QueryF1DB

# %%
# Create an instance of QueryF1DB
query_module = QueryF1DB()

query_module.query_circuits_per_country()
# Out:
#           country  num_circuits
# 0       Argentina             1
# 1       Australia             2
# 2         Austria             2
# 3      Azerbaijan             1
# 4         Bahrain             1
# 5         Belgium             3
# 6          Brazil             2
# 7          Canada             3
# 8           China             1
# 9          France             7
# 10        Germany             3
# 11        Hungary             1
# 12          India             1
# 13          Italy             4
# 14          Japan             3
# 15          Korea             1
# 16       Malaysia             1
# 17         Mexico             1
# 18         Monaco             1
# 19        Morocco             1
# 20    Netherlands             1
# 21       Portugal             4
# 22          Qatar             1
# 23         Russia             1
# 24   Saudi Arabia             1
# 25      Singapore             1
# 26   South Africa             2
# 27          Spain             6
# ...

# %%
query_module.query_races_per_season()
# Out:
#     year  num_races
# 0   1950          7
# 1   1951          8
# 2   1952          8
# 3   1953          9
# 4   1954          9
# ..   ...        ...
# 69  2019         21
# 70  2020         17
# 71  2021         22
# 72  2022         22
# 73  2023         22
#
# [74 rows x 2 columns]

# %%
query_module.query_constructors_per_nationality()
# Out:
#       nationality  num_constructors
# 0        American                39
# 1      Australian                 1
# 2        Austrian                 1
# 3         Belgian                 1
# 4       Brazilian                 1
# 5         British                86
# 6        Canadian                 2
# 7           Dutch                 3
# 8     East German                 1
# 9          French                13
# 10         German                10
# 11      Hong Kong                 1
# 12         Indian                 1
# 13          Irish                 1
# 14        Italian                29
# 15       Japanese                 5
# 16      Malaysian                 2
# 17        Mexican                 1
# 18  New Zealander                 1
# 19      Rhodesian                 1
# 20        Russian                 2
# 21  South African                 3
# 22        Spanish                 1
# 23          Swiss                 5

# %%
query_module.query_constructor_points()
# Out:
#      constructorId  total_points
# 0                1        6390.5
# 1                2         308.0
# 2                3        3626.0
# 3                4        1777.0
# 4                5         500.0
# ..             ...           ...
# 169            209           1.0
# 170            210         249.0
# 171            211         283.0
# 172            213         309.0
# 173            214         448.0
#
# [174 rows x 2 columns]

# %%
query_module.query_constructor_participation()
# Out:
#      constructorId  num_participations
# 0                1                 905
# 1                2                  71
# 2                3                 819
# 3                4                 403
# 4                5                 268
# ..             ...                 ...
# 169            209                  39
# 170            210                 166
# 171            211                  38
# 172            213                  83
# 173            214                  66
#
# [174 rows x 2 columns]

# %%
# Create an instance of VisQueryF1DB
vis_query = VisQueryF1DB(query_module)
vis_query.plot_circuits_per_country()

# %%
vis_query.plot_races_per_season()

# %%
vis_query.plot_constructors_per_nationality()

# %%
vis_query.plot_constructor_points()

# %%
vis_query.plot_constructor_participation()
